# %% [markdown]
# ## Titanic Data Exploration ##
#
# ***
#
# Over the past several weeks, you've learned the code about how to explore and manipulate a dataset. Now it's time to practice what you've learned on a real-world dataset.
#
# ***
#
# ### Titanic Dataset
#
# The titanic dataset holds information about the passengers on the titanic. This includes passenger name, characteristics, and if they survived the accident. The dataset has the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# If you need some additional motivation before starting, please visit: https://www.youtube.com/watch?v=3gK_2XdjOdY
#
# ### How to work through the dataset:
#
# Follow the prompts below to explore, manipulate, and visualize aspects of the dataset. Working with data takes time, so take your time as you start with a messy dataset and turn it into something that shows meaningful visualizations.
#
# ***

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Libraries and Dataset
#
# * Review the entire notebook to determine what you will be expected to do - then, import the necessary libraries
# * Import the titanic.xlsx dataset

# %%
tt = pd.read_excel("datasets/titanic.xlsx")
tt.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Determine the Characteristics of the Dataset
#
#    * How many columns are in this dataset?
#    * How many rows are in this dataset?
#    * What types of data are in each column? Does this make sense with that you know about that column?
#    * Which variables are numeric? Which variables are categorical? What other variables are left outside of these two groups?
#    * Which variable could be considered a 'dependent' variable?

# %%
tt.info()
#14 columns
#1309 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# ### Identify the Missing Data in the Dataset
#
#    * Is there any missing data?
#    * Which columns have any missing data?
#    * Which column has the most missing information? Which column has the least?

# %%
#yes
#5, 8,9,10,11,12,13
#13 has most9 has least missing data

# %% [markdown]
# ### Handling the Missing Data in the Dataset
#
#    * Remove the columns with excessive missing data (any column missing greater than 500 rows)
#    * When there is very little missing data, we can make replacements. Replace the missing data for the "embarked" column with the most common embarkation point.
#    * Replace the missing data in "fare" with the average fare of the entire sample.
#    * Remove the rows in the dataset that has missing "age" data.
#    * Recheck is there is any data missing in the dataset.

# %%
tt.drop("body", axis = 1, inplace = True)
tt.head(30)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
# 20       1         1                      Beckwith, Mr. Richard Leonard
# 21       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1         1                              Behr, Mr. Karl Howell
# 23       1         1                              Bidois, Miss. Rosalie
# 24       1         1                                  Bird, Miss. Ellen
# 25       1         0                                Birnbaum, Mr. Jakob
# 26       1         1                            Bishop, Mr. Dickinson H
# 27       1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1         1                             Bissette, Miss. Amelia
# 29       1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
#
#        sex      age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0   female  29.0000      0      0     24160  211.3375       B5        S    2
# 1     male   0.9167      1      2    113781  151.5500  C22 C26        S   11
# 2   female   2.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 3     male  30.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 4   female  25.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 5     male  48.0000      0      0     19952   26.5500      E12        S    3
# 6   female  63.0000      1      0     13502   77.9583       D7        S   10
# 7     male  39.0000      0      0    112050    0.0000      A36        S  NaN
# 8   female  53.0000      2      0     11769   51.4792     C101        S    D
# 9     male  71.0000      0      0  PC 17609   49.5042      NaN        C  NaN
# 10    male  47.0000      1      0  PC 17757  227.5250  C62 C64        C  NaN
# 11  female  18.0000      1      0  PC 17757  227.5250  C62 C64        C    4
# 12  female  24.0000      0      0  PC 17477   69.3000      B35        C    9
# 13  female  26.0000      0      0     19877   78.8500      NaN        S    6
# 14    male  80.0000      0      0     27042   30.0000      A23        S    B
# 15    male      NaN      0      0  PC 17318   25.9250      NaN        S  NaN
# 16    male  24.0000      0      1  PC 17558  247.5208  B58 B60        C  NaN
# 17  female  50.0000      0      1  PC 17558  247.5208  B58 B60        C    6
# 18  female  32.0000      0      0     11813   76.2917      D15        C    8
# 19    male  36.0000      0      0     13050   75.2417       C6        C    A
# 20    male  37.0000      1      1     11751   52.5542      D35        S    5
# 21  female  47.0000      1      1     11751   52.5542      D35        S    5
# 22    male  26.0000      0      0    111369   30.0000     C148        C    5
# 23  female  42.0000      0      0  PC 17757  227.5250      NaN        C    4
# 24  female  29.0000      0      0  PC 17483  221.7792      C97        S    8
# 25    male  25.0000      0      0     13905   26.0000      NaN        C  NaN
# 26    male  25.0000      1      0     11967   91.0792      B49        C    7
# 27  female  19.0000      1      0     11967   91.0792      B49        C    7
# 28  female  35.0000      0      0  PC 17760  135.6333      C99        S    8
# 29    male  28.0000      0      0    110564   26.5500      C52        S    D
#
#                              home.dest
# 0                         St Louis, MO
# 1      Montreal, PQ / Chesterville, ON
# 2      Montreal, PQ / Chesterville, ON
# 3      Montreal, PQ / Chesterville, ON
# 4      Montreal, PQ / Chesterville, ON
# 5                         New York, NY
# 6                           Hudson, NY
# 7                          Belfast, NI
# 8                  Bayside, Queens, NY
# 9                  Montevideo, Uruguay
# 10                        New York, NY
# 11                        New York, NY
# 12                       Paris, France
# 13                                 NaN
# 14                       Hessle, Yorks
# 15                        New York, NY
# 16                        Montreal, PQ
# 17                        Montreal, PQ
# 18                                 NaN
# 19                        Winnipeg, MN
# 20                        New York, NY
# 21                        New York, NY
# 22                        New York, NY
# 23                                 NaN
# 24                                 NaN
# 25                   San Francisco, CA
# 26                        Dowagiac, MI
# 27                        Dowagiac, MI
# 28                                 NaN
# 29  Stockholm, Sweden / Washington, DC

# %%
tt.mode()
# Out:
#    pclass  survived                  name   sex   age  sibsp  parch    ticket  \
# 0     3.0       0.0  Connolly, Miss. Kate  male  24.0    0.0    0.0  CA. 2343
# 1     NaN       NaN      Kelly, Mr. James   NaN   NaN    NaN    NaN       NaN
#
#    fare        cabin embarked boat     home.dest
# 0  8.05  C23 C25 C27        S   13  New York, NY
# 1   NaN          NaN      NaN  NaN           NaN

# %%
tt["embarked"].replace(np.nan, "S")
tt.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0  29.0000      0      0     24160  211.3375       B5        S    2
# 1   0.9167      1      2    113781  151.5500  C22 C26        S   11
# 2   2.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 3  30.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 4  25.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 5  48.0000      0      0     19952   26.5500      E12        S    3
# 6  63.0000      1      0     13502   77.9583       D7        S   10
# 7  39.0000      0      0    112050    0.0000      A36        S  NaN
# 8  53.0000      2      0     11769   51.4792     C101        S    D
# 9  71.0000      0      0  PC 17609   49.5042      NaN        C  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
tt.loc[tt["cabin"] == np.nan]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, home.dest]
# Index: []

# %%
x = tt["fare"].mean()

tt["fare"].replace(np.nan, x)
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64

# %%
tt.dropna(subset=["age"], inplace = True)
tt.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 0  29.0000      0      0     24160  211.3375       B5        S    2
# 1   0.9167      1      2    113781  151.5500  C22 C26        S   11
# 2   2.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 3  30.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 4  25.0000      1      2    113781  151.5500  C22 C26        S  NaN
# 5  48.0000      0      0     19952   26.5500      E12        S    3
# 6  63.0000      1      0     13502   77.9583       D7        S   10
# 7  39.0000      0      0    112050    0.0000      A36        S  NaN
# 8  53.0000      2      0     11769   51.4792     C101        S    D
# 9  71.0000      0      0  PC 17609   49.5042      NaN        C  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1046 non-null   int64
#  1   survived   1046 non-null   int64
#  2   name       1046 non-null   object
#  3   sex        1046 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1046 non-null   int64
#  6   parch      1046 non-null   int64
#  7   ticket     1046 non-null   object
#  8   fare       1045 non-null   float64
#  9   cabin      272 non-null    object
#  10  embarked   1044 non-null   object
#  11  boat       417 non-null    object
#  12  home.dest  685 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 114.4+ KB

# %% [markdown]
# ### Creating Columns and Replacing Labels
#
#    * Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#    * Create a new column called "Titanic Passenger" and make all values 1
#    * Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
#    * Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.
#    * Create a column called "Has Caregiver" - this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, otherwise the value should be 0.
#    * Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
#    * Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). You can use bins to complete this (or any other method you like). You define the cutoff points for each group you create.
#
# After create new columns, replace the basic coding "0/1" with meaningful labels.

# %%
tt["embarked"].replace("S", "Southhampton", inplace = True)

tt.head()

tt["embarked"].value_counts()

tt.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0     24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2    113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2    113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2    113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2    113781  151.5500  C22 C26  Southhampton  NaN
# 5  48.0000      0      0     19952   26.5500      E12  Southhampton    3
# 6  63.0000      1      0     13502   77.9583       D7  Southhampton   10
# 7  39.0000      0      0    112050    0.0000      A36  Southhampton  NaN
# 8  53.0000      2      0     11769   51.4792     C101  Southhampton    D
# 9  71.0000      0      0  PC 17609   49.5042      NaN             C  NaN
#
#                          home.dest  Titanic Passenger
# 0                     St Louis, MO                  1
# 1  Montreal, PQ / Chesterville, ON                  1
# 2  Montreal, PQ / Chesterville, ON                  1
# 3  Montreal, PQ / Chesterville, ON                  1
# 4  Montreal, PQ / Chesterville, ON                  1
# 5                     New York, NY                  1
# 6                       Hudson, NY                  1
# 7                      Belfast, NI                  1
# 8              Bayside, Queens, NY                  1
# 9              Montevideo, Uruguay                  1

# %%
tt["survived"].replace("Yes", 1, inplace = True)
tt["survived"].replace("No", 0, inplace = True)
tt.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2  113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
#
#                          home.dest  Titanic Passenger  Family Size  \
# 0                     St Louis, MO                  1            0
# 1  Montreal, PQ / Chesterville, ON                  1            3
# 2  Montreal, PQ / Chesterville, ON                  1            3
# 3  Montreal, PQ / Chesterville, ON                  1            3
# 4  Montreal, PQ / Chesterville, ON                  1            3
#
#    Travel Alone  Has Caregiver  Crew Age Group
# 0             1              0     0     adult
# 1             0              1     1    infant
# 2             0              0     1    infant
# 3             0              0     1     adult
# 4             0              0     1     adult

# %%
tt["Titanic Passenger"] = 1

# %%
tt["Family Size"] =  tt["sibsp"]+ tt["parch"]
tt.head()
# Out:
#    pclass survived                                             name     sex  \
# 0       1      Yes                    Allen, Miss. Elisabeth Walton  female
# 1       1      Yes                   Allison, Master. Hudson Trevor    male
# 2       1       No                     Allison, Miss. Helen Loraine  female
# 3       1       No             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       No  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2  113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
#
#                          home.dest  Titanic Passenger  Family Size
# 0                     St Louis, MO                  1            0
# 1  Montreal, PQ / Chesterville, ON                  1            3
# 2  Montreal, PQ / Chesterville, ON                  1            3
# 3  Montreal, PQ / Chesterville, ON                  1            3
# 4  Montreal, PQ / Chesterville, ON                  1            3

# %%
tt["Travel Alone"] = np.where(tt["Family Size"] > 0, 0, 1)
tt.head()
# Out:
#    pclass survived                                             name     sex  \
# 0       1      Yes                    Allen, Miss. Elisabeth Walton  female
# 1       1      Yes                   Allison, Master. Hudson Trevor    male
# 2       1       No                     Allison, Miss. Helen Loraine  female
# 3       1       No             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       No  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2  113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
#
#                          home.dest  Titanic Passenger  Family Size  \
# 0                     St Louis, MO                  1            0
# 1  Montreal, PQ / Chesterville, ON                  1            3
# 2  Montreal, PQ / Chesterville, ON                  1            3
# 3  Montreal, PQ / Chesterville, ON                  1            3
# 4  Montreal, PQ / Chesterville, ON                  1            3
#
#    Travel Alone
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0

# %%
tt["Has Caregiver"] = np.where((tt["age"] < 13 & tt["Family Size"]) > 0, 1, 0)
tt.head()
# Out:
#    pclass survived                                             name     sex  \
# 0       1      Yes                    Allen, Miss. Elisabeth Walton  female
# 1       1      Yes                   Allison, Master. Hudson Trevor    male
# 2       1       No                     Allison, Miss. Helen Loraine  female
# 3       1       No             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       No  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2  113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
#
#                          home.dest  Titanic Passenger  Family Size  \
# 0                     St Louis, MO                  1            0
# 1  Montreal, PQ / Chesterville, ON                  1            3
# 2  Montreal, PQ / Chesterville, ON                  1            3
# 3  Montreal, PQ / Chesterville, ON                  1            3
# 4  Montreal, PQ / Chesterville, ON                  1            3
#
#    Travel Alone  Has Caregiver
# 0             1              0
# 1             0              1
# 2             0              0
# 3             0              0
# 4             0              0

# %%
tt["Crew"] = np.where(tt["parch"] > 0, 1, 0)
tt.head()
# Out:
#    pclass survived                                             name     sex  \
# 0       1      Yes                    Allen, Miss. Elisabeth Walton  female
# 1       1      Yes                   Allison, Master. Hudson Trevor    male
# 2       1       No                     Allison, Miss. Helen Loraine  female
# 3       1       No             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       No  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin      embarked boat  \
# 0  29.0000      0      0   24160  211.3375       B5  Southhampton    2
# 1   0.9167      1      2  113781  151.5500  C22 C26  Southhampton   11
# 2   2.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
# 4  25.0000      1      2  113781  151.5500  C22 C26  Southhampton  NaN
#
#                          home.dest  Titanic Passenger  Family Size  \
# 0                     St Louis, MO                  1            0
# 1  Montreal, PQ / Chesterville, ON                  1            3
# 2  Montreal, PQ / Chesterville, ON                  1            3
# 3  Montreal, PQ / Chesterville, ON                  1            3
# 4  Montreal, PQ / Chesterville, ON                  1            3
#
#    Travel Alone  Has Caregiver  Crew
# 0             1              0     0
# 1             0              1     1
# 2             0              0     1
# 3             0              0     1
# 4             0              0     1

# %%
bins = [0, 3, 12, 18, 65, 120]

labels = ["infant", "child", "teen", "adult", "senior"]


tt["Age Group"] = pd.cut(tt["age"], bins, labels = labels)

tt.head(20)
# Out:
#     pclass survived                                               name  \
# 0        1      Yes                      Allen, Miss. Elisabeth Walton
# 1        1      Yes                     Allison, Master. Hudson Trevor
# 2        1       No                       Allison, Miss. Helen Loraine
# 3        1       No               Allison, Mr. Hudson Joshua Creighton
# 4        1       No    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1      Yes                                Anderson, Mr. Harry
# 6        1      Yes                  Andrews, Miss. Kornelia Theodosia
# 7        1       No                             Andrews, Mr. Thomas Jr
# 8        1      Yes      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1       No                            Artagaveytia, Mr. Ramon
# 10       1       No                             Astor, Col. John Jacob
# 11       1      Yes  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1      Yes                      Aubart, Mme. Leontine Pauline
# 13       1      Yes                       Barber, Miss. Ellen "Nellie"
# 14       1      Yes               Barkworth, Mr. Algernon Henry Wilson
# 16       1       No                           Baxter, Mr. Quigg Edmond
# 17       1      Yes    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1      Yes                              Bazzani, Miss. Albina
# 19       1       No                               Beattie, Mr. Thomson
# 20       1      Yes                      Beckwith, Mr. Richard Leonard
#
#        sex      age  sibsp  parch    ticket      fare    cabin      embarked  \
# 0   female  29.0000      0      0     24160  211.3375       B5  Southhampton
# 1     male   0.9167      1      2    113781  151.5500  C22 C26  Southhampton
# 2   female   2.0000      1      2    113781  151.5500  C22 C26  Southhampton
# 3     male  30.0000      1      2    113781  151.5500  C22 C26  Southhampton
# 4   female  25.0000      1      2    113781  151.5500  C22 C26  Southhampton
# 5     male  48.0000      0      0     19952   26.5500      E12  Southhampton
# 6   female  63.0000      1      0     13502   77.9583       D7  Southhampton
# 7     male  39.0000      0      0    112050    0.0000      A36  Southhampton
# 8   female  53.0000      2      0     11769   51.4792     C101  Southhampton
# 9     male  71.0000      0      0  PC 17609   49.5042      NaN             C
# 10    male  47.0000      1      0  PC 17757  227.5250  C62 C64             C
# 11  female  18.0000      1      0  PC 17757  227.5250  C62 C64             C
# 12  female  24.0000      0      0  PC 17477   69.3000      B35             C
# 13  female  26.0000      0      0     19877   78.8500      NaN  Southhampton
# 14    male  80.0000      0      0     27042   30.0000      A23  Southhampton
# 16    male  24.0000      0      1  PC 17558  247.5208  B58 B60             C
# 17  female  50.0000      0      1  PC 17558  247.5208  B58 B60             C
# 18  female  32.0000      0      0     11813   76.2917      D15             C
# 19    male  36.0000      0      0     13050   75.2417       C6             C
# 20    male  37.0000      1      1     11751   52.5542      D35  Southhampton
#
#    boat                        home.dest  Titanic Passenger  Family Size  \
# 0     2                     St Louis, MO                  1            0
# 1    11  Montreal, PQ / Chesterville, ON                  1            3
# 2   NaN  Montreal, PQ / Chesterville, ON                  1            3
# 3   NaN  Montreal, PQ / Chesterville, ON                  1            3
# 4   NaN  Montreal, PQ / Chesterville, ON                  1            3
# 5     3                     New York, NY                  1            0
# 6    10                       Hudson, NY                  1            1
# 7   NaN                      Belfast, NI                  1            0
# 8     D              Bayside, Queens, NY                  1            2
# 9   NaN              Montevideo, Uruguay                  1            0
# 10  NaN                     New York, NY                  1            1
# 11    4                     New York, NY                  1            1
# 12    9                    Paris, France                  1            0
# 13    6                              NaN                  1            0
# 14    B                    Hessle, Yorks                  1            0
# 16  NaN                     Montreal, PQ                  1            1
# 17    6                     Montreal, PQ                  1            1
# 18    8                              NaN                  1            0
# 19    A                     Winnipeg, MN                  1            0
# 20    5                     New York, NY                  1            2
#
#     Travel Alone  Has Caregiver  Crew Age Group
# 0              1              0     0     adult
# 1              0              1     1    infant
# 2              0              0     1    infant
# 3              0              0     1     adult
# 4              0              0     1     adult
# 5              1              0     0     adult
# 6              0              0     0     adult
# 7              1              0     0     adult
# 8              0              0     0     adult
# 9              1              0     0    senior
# 10             0              0     0     adult
# 11             0              0     0      teen
# 12             1              0     0     adult
# 13             1              0     0     adult
# 14             1              0     0    senior
# 16             0              0     1     adult
# 17             0              0     1     adult
# 18             1              0     0     adult
# 19             1              0     0     adult
# 20             0              0     1     adult

# %% [markdown]
# ### Determine Frequencies of Groups
#
# * How many passengers fall into each category? Determine how many passengers fall into each group for <b>each</b> categorical vairable (including the ones you just created).

# %%
tt["Age Group"].value_counts()
# Out:
# adult     843
# teen       99
# child      53
# infant     41
# senior     10
# Name: Age Group, dtype: int64

# %%
tt.head(50)
# Out:
#     pclass survived                                               name  \
# 0        1      Yes                      Allen, Miss. Elisabeth Walton
# 1        1      Yes                     Allison, Master. Hudson Trevor
# 2        1       No                       Allison, Miss. Helen Loraine
# 3        1       No               Allison, Mr. Hudson Joshua Creighton
# 4        1       No    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1      Yes                                Anderson, Mr. Harry
# 6        1      Yes                  Andrews, Miss. Kornelia Theodosia
# 7        1       No                             Andrews, Mr. Thomas Jr
# 8        1      Yes      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1       No                            Artagaveytia, Mr. Ramon
# 10       1       No                             Astor, Col. John Jacob
# 11       1      Yes  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1      Yes                      Aubart, Mme. Leontine Pauline
# 13       1      Yes                       Barber, Miss. Ellen "Nellie"
# 14       1      Yes               Barkworth, Mr. Algernon Henry Wilson
# 16       1       No                           Baxter, Mr. Quigg Edmond
# 17       1      Yes    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1      Yes                              Bazzani, Miss. Albina
# 19       1       No                               Beattie, Mr. Thomson
# 20       1      Yes                      Beckwith, Mr. Richard Leonard
# 21       1      Yes   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22       1      Yes                              Behr, Mr. Karl Howell
# 23       1      Yes                              Bidois, Miss. Rosalie
# 24       1      Yes                                  Bird, Miss. Ellen
# 25       1       No                                Birnbaum, Mr. Jakob
# 26       1      Yes                            Bishop, Mr. Dickinson H
# 27       1      Yes            Bishop, Mrs. Dickinson H (Helen Walton)
# 28       1      Yes                             Bissette, Miss. Amelia
# 29       1      Yes          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30       1       No                       Blackwell, Mr. Stephen Weart
# 31       1      Yes                                   Blank, Mr. Henry
# 32       1      Yes                            Bonnell, Miss. Caroline
# 33       1      Yes                           Bonnell, Miss. Elizabeth
# 34       1       No                           Borebank, Mr. John James
# 35       1      Yes                           Bowen, Miss. Grace Scott
# 36       1      Yes                        Bowerman, Miss. Elsie Edith
# 38       1       No                            Brady, Mr. John Bertram
# 39       1       No                                 Brandeis, Mr. Emil
# 41       1      Yes          Brown, Mrs. James Joseph (Margaret Tobin)
# 42       1      Yes     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43       1      Yes    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44       1      Yes                    Burns, Miss. Elizabeth Margaret
# 45       1       No                  Butt, Major. Archibald Willingham
# 47       1      Yes                  Calderhead, Mr. Edward Pennington
# 48       1      Yes   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49       1      Yes                 Cardeza, Mr. Thomas Drake Martinez
# 50       1      Yes  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 51       1       No                           Carlsson, Mr. Frans Olof
# 52       1       No                            Carrau, Mr. Francisco M
# 53       1       No                             Carrau, Mr. Jose Pedro
#
#        sex      age  sibsp  parch    ticket      fare        cabin  \
# 0   female  29.0000      0      0     24160  211.3375           B5
# 1     male   0.9167      1      2    113781  151.5500      C22 C26
# 2   female   2.0000      1      2    113781  151.5500      C22 C26
# 3     male  30.0000      1      2    113781  151.5500      C22 C26
# 4   female  25.0000      1      2    113781  151.5500      C22 C26
# 5     male  48.0000      0      0     19952   26.5500          E12
# 6   female  63.0000      1      0     13502   77.9583           D7
# 7     male  39.0000      0      0    112050    0.0000          A36
# 8   female  53.0000      2      0     11769   51.4792         C101
# 9     male  71.0000      0      0  PC 17609   49.5042          NaN
# 10    male  47.0000      1      0  PC 17757  227.5250      C62 C64
# 11  female  18.0000      1      0  PC 17757  227.5250      C62 C64
# 12  female  24.0000      0      0  PC 17477   69.3000          B35
# 13  female  26.0000      0      0     19877   78.8500          NaN
# 14    male  80.0000      0      0     27042   30.0000          A23
# 16    male  24.0000      0      1  PC 17558  247.5208      B58 B60
# 17  female  50.0000      0      1  PC 17558  247.5208      B58 B60
# 18  female  32.0000      0      0     11813   76.2917          D15
# 19    male  36.0000      0      0     13050   75.2417           C6
# 20    male  37.0000      1      1     11751   52.5542          D35
# 21  female  47.0000      1      1     11751   52.5542          D35
# 22    male  26.0000      0      0    111369   30.0000         C148
# 23  female  42.0000      0      0  PC 17757  227.5250          NaN
# 24  female  29.0000      0      0  PC 17483  221.7792          C97
# 25    male  25.0000      0      0     13905   26.0000          NaN
# 26    male  25.0000      1      0     11967   91.0792          B49
# 27  female  19.0000      1      0     11967   91.0792          B49
# 28  female  35.0000      0      0  PC 17760  135.6333          C99
# 29    male  28.0000      0      0    110564   26.5500          C52
# 30    male  45.0000      0      0    113784   35.5000            T
# 31    male  40.0000      0      0    112277   31.0000          A31
# 32  female  30.0000      0      0     36928  164.8667           C7
# 33  female  58.0000      0      0    113783   26.5500         C103
# 34    male  42.0000      0      0    110489   26.5500          D22
# 35  female  45.0000      0      0  PC 17608  262.3750          NaN
# 36  female  22.0000      0      1    113505   55.0000          E33
# 38    male  41.0000      0      0    113054   30.5000          A21
# 39    male  48.0000      0      0  PC 17591   50.4958          B10
# 41  female  44.0000      0      0  PC 17610   27.7208           B4
# 42  female  59.0000      2      0     11769   51.4792         C101
# 43  female  60.0000      0      0     11813   76.2917          D15
# 44  female  41.0000      0      0     16966  134.5000          E40
# 45    male  45.0000      0      0    113050   26.5500          B38
# 47    male  42.0000      0      0  PC 17476   26.2875          E24
# 48  female  53.0000      0      0  PC 17606   27.4458          NaN
# 49    male  36.0000      0      1  PC 17755  512.3292  B51 B53 B55
# 50  female  58.0000      0      1  PC 17755  512.3292  B51 B53 B55
# 51    male  33.0000      0      0       695    5.0000  B51 B53 B55
# 52    male  28.0000      0      0    113059   47.1000          NaN
# 53    male  17.0000      0      0    113059   47.1000          NaN
#
#         embarked boat                                       home.dest  \
# 0   Southhampton    2                                    St Louis, MO
# 1   Southhampton   11                 Montreal, PQ / Chesterville, ON
# 2   Southhampton  NaN                 Montreal, PQ / Chesterville, ON
# 3   Southhampton  NaN                 Montreal, PQ / Chesterville, ON
# 4   Southhampton  NaN                 Montreal, PQ / Chesterville, ON
# 5   Southhampton    3                                    New York, NY
# 6   Southhampton   10                                      Hudson, NY
# 7   Southhampton  NaN                                     Belfast, NI
# 8   Southhampton    D                             Bayside, Queens, NY
# 9              C  NaN                             Montevideo, Uruguay
# 10             C  NaN                                    New York, NY
# 11             C    4                                    New York, NY
# 12             C    9                                   Paris, France
# 13  Southhampton    6                                             NaN
# 14  Southhampton    B                                   Hessle, Yorks
# 16             C  NaN                                    Montreal, PQ
# 17             C    6                                    Montreal, PQ
# 18             C    8                                             NaN
# 19             C    A                                    Winnipeg, MN
# 20  Southhampton    5                                    New York, NY
# 21  Southhampton    5                                    New York, NY
# 22             C    5                                    New York, NY
# 23             C    4                                             NaN
# 24  Southhampton    8                                             NaN
# 25             C  NaN                               San Francisco, CA
# 26             C    7                                    Dowagiac, MI
# 27             C    7                                    Dowagiac, MI
# 28  Southhampton    8                                             NaN
# 29  Southhampton    D              Stockholm, Sweden / Washington, DC
# 30  Southhampton  NaN                                     Trenton, NJ
# 31             C    7                                  Glen Ridge, NJ
# 32  Southhampton    8                                  Youngstown, OH
# 33  Southhampton    8               Birkdale, England Cleveland, Ohio
# 34  Southhampton  NaN                           London / Winnipeg, MB
# 35             C    4                                 Cooperstown, NY
# 36  Southhampton    6                St Leonards-on-Sea, England Ohio
# 38  Southhampton  NaN                                     Pomeroy, WA
# 39             C  NaN                                       Omaha, NE
# 41             C    6                                      Denver, CO
# 42  Southhampton    D                                     Belmont, MA
# 43             C    8                                Philadelphia, PA
# 44             C    3                                             NaN
# 45  Southhampton  NaN                                  Washington, DC
# 47  Southhampton    5                                    New York, NY
# 48             C    6                                  Washington, DC
# 49             C    3  Austria-Hungary / Germantown, Philadelphia, PA
# 50             C    3                    Germantown, Philadelphia, PA
# 51  Southhampton  NaN                                    New York, NY
# 52  Southhampton  NaN                             Montevideo, Uruguay
# 53  Southhampton  NaN                             Montevideo, Uruguay
#
#     Titanic Passenger  Family Size  Travel Alone  Has Caregiver  Crew  \
# 0                   1            0             1              0     0
# 1                   1            3             0              1     1
# 2                   1            3             0              0     1
# 3                   1            3             0              0     1
# 4                   1            3             0              0     1
# 5                   1            0             1              0     0
# 6                   1            1             0              0     0
# 7                   1            0             1              0     0
# 8                   1            2             0              0     0
# 9                   1            0             1              0     0
# 10                  1            1             0              0     0
# 11                  1            1             0              0     0
# 12                  1            0             1              0     0
# 13                  1            0             1              0     0
# 14                  1            0             1              0     0
# 16                  1            1             0              0     1
# 17                  1            1             0              0     1
# 18                  1            0             1              0     0
# 19                  1            0             1              0     0
# 20                  1            2             0              0     1
# 21                  1            2             0              0     1
# 22                  1            0             1              0     0
# 23                  1            0             1              0     0
# 24                  1            0             1              0     0
# 25                  1            0             1              0     0
# 26                  1            1             0              0     0
# 27                  1            1             0              0     0
# 28                  1            0             1              0     0
# 29                  1            0             1              0     0
# 30                  1            0             1              0     0
# 31                  1            0             1              0     0
# 32                  1            0             1              0     0
# 33                  1            0             1              0     0
# 34                  1            0             1              0     0
# 35                  1            0             1              0     0
# 36                  1            1             0              0     1
# 38                  1            0             1              0     0
# 39                  1            0             1              0     0
# 41                  1            0             1              0     0
# 42                  1            2             0              0     0
# 43                  1            0             1              0     0
# 44                  1            0             1              0     0
# 45                  1            0             1              0     0
# 47                  1            0             1              0     0
# 48                  1            0             1              0     0
# 49                  1            1             0              0     1
# 50                  1            1             0              0     1
# 51                  1            0             1              0     0
# 52                  1            0             1              0     0
# 53                  1            0             1              0     0
#
#    Age Group
# 0      adult
# 1     infant
# 2     infant
# 3      adult
# 4      adult
# 5      adult
# 6      adult
# 7      adult
# 8      adult
# 9     senior
# 10     adult
# 11      teen
# 12     adult
# 13     adult
# 14    senior
# 16     adult
# 17     adult
# 18     adult
# 19     adult
# 20     adult
# 21     adult
# 22     adult
# 23     adult
# 24     adult
# 25     adult
# 26     adult
# 27     adult
# 28     adult
# 29     adult
# 30     adult
# 31     adult
# 32     adult
# 33     adult
# 34     adult
# 35     adult
# 36     adult
# 38     adult
# 39     adult
# 41     adult
# 42     adult
# 43     adult
# 44     adult
# 45     adult
# 47     adult
# 48     adult
# 49     adult
# 50     adult
# 51     adult
# 52     adult
# 53      teen

# %% [markdown]
# ### Determine the Distribution of Numeric Data
#
# * What are the summary statistics for <b>each</b> numeric variable in the dataset? Summary statistics include:
#     * Mean
#     * Median
#     * Mode
#     * Standard Deviation
#     * Range

# %%
tt["Age Group"].mode()
# Out:
# 0    adult
# Name: Age Group, dtype: category
# Categories (5, object): ['infant' < 'child' < 'teen' < 'adult' < 'senior']

# %%
tt["fare"].mean()
# Out:
# 36.686080287081474

# %%
tt["age"].std()
# Out:
# 14.413499699923594

# %% [markdown]
# ### Relationships between Variables
#
# * Determine the relationship between each variable and the variable "survived". This is our primary variable of interest -- did this passenger survive the accident? Did the characteristics of the passenger have any relationship with their survival?
#     * <b>pclass</b>: how many survivors are in each passenger class? does a pattern emerge? which class has the most survivors? which has the least?
#     * <b>sex</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>age</b>: how does the average age of the passenger differ based on survival group?
#     * <b>age group</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>family size</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>travel alone</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>crew</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>has caregiver</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>fare</b>: how does the average fare the passenger paid differ based on survival group?
#     * <b>embarked</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#
# Based on what you learn working through this section, make (2) statements about what characteristics of passenger most influenced their survival.

# %%
tt["pclass"].groupby(tt["survived"]).std()
# Out:
# survived
# 0    0.760931
# 1    0.847733
# Name: pclass, dtype: float64

# %%
tt["survived"].groupby(tt["sex"]).std()
# Out:
# sex
# female    0.432072
# male      0.404131
# Name: survived, dtype: float64

# %%
tt["age"].groupby(tt["survived"]).mean()
# Out:
# survived
# 0    30.545369
# 1    28.918228
# Name: age, dtype: float64

# %% [markdown]
# ### Visualize your Results
#
# * Using the most interesting (from your POV) results from the above section, create (3) visualizations to illustrate the results.
# * Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?
# * Create a violin plot to show the distribution of age across passenger class.
